# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{query_url}&q={city.replace(' ', '+')}"
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%m/%d/%y,%H:%M:%S")
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | marshall
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | buchanan
# Processing Record 7 of Set 1 | nanortalik
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | tokur
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | siderno
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | nova aurora
# Processing Record 15 of Set 1 | gamba
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 1 | shimoda
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | balaghat
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | cadiz
# Processing Record 24 of Set 1 | camana
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | ashtian
# Processing Record 27 of Set 1 | kieta
# Processing Record 28 of Set 1 | rajapur
# Processing Record 29 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | labuhan
# Processing Record 32 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | anisoc
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | la asuncion
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | nizhniy tsasuchey
# Processing Record 39 of Set 1 | puerto del rosario
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | tabas
# Processing Record 42 of Set 1 | silifke
# Processing Record 43 of Set 1 | likasi
# Processing Record 44 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 1 | concordia
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | terracina
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | cidreira
# Processing Record 0 of Set 2 | ixtiyucan
# City not found. Skipping...
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | sola
# Processing Record 3 of Set 2 | majene
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | bambanglipuro
# Processing Record 10 of Set 2 | severo-kurilsk
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | vao
# Processing Record 13 of Set 2 | touros
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | banamba
# Processing Record 18 of Set 2 | richards bay
# Processing Record 19 of Set 2 | karaul
# Processing Record 42 of Set 3 | hermanus
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | golden
# Processing Record 45 of Set 3 | new norfolk
# Processing Record 46 of Set 3 | agadez
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | korla
# Processing Record 0 of Set 4 | bambous virieux
# Processing Record 1 of Set 4 | makakilo city
# Processing Record 2 of Set 4 | manhuacu
# Processing Record 3 of Set 4 | alofi
# Processing Record 4 of Set 4 | tabuk
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | knysna
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | rio grande
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | ayan
# Processing Record 14 of Set 4 | zhezkazgan
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | atuona
# Processing Record 20 of Set 4 | katherine
# Processing Record 21 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 4 | alihe
# Processing Record 23 of Set 4 | maragogi
# Processing Record 24 of Set 4 | mamakan
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | starkville
# Processing Record 27 of Set 4 | longyearbyen
# Processing Record 28 of Set 4 | aguimes
# Processing Record 29 of Set 4 | oktyabrskiy
# Processing Record 30 of Set 4 | thinadhoo
# Processing Record 31 of Set 4 | stornoway
# Processing Record 32 of Set 4 | simpang
# Processing Record 33 of Set 4 | asyut
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | sitka
# Processing Record 37 of Set 4 | santa fe
# Processing Record 38 of Set 4 | birao
# Processing Record 39 of Set 4 | daru
# Processing Record 40 of Set 4 | bacolod
# Processing Record 41 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 4 | tiarei
# Processing Record 43 of Set 4 | sur
# Processing Record 44 of Set 4 | newport
# Processing Record 45 of Set 4 | hearst
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | bluff
# Processing Record 48 of Set 4 | port elizabeth
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 0 of Set 5 | port keats
# Processing Record 1 of Set 5 | thunder bay
# Processing Record 2 of Set 5 | cururupu
# Processing Record 3 of Set 5 | vestmanna
# Processing Record 4 of Set 5 | iskateley
# Processing Record 5 of Set 5 | beihai
# Processing Record 6 of Set 5 | puerto pinasco
# City not found. Skipping...
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | mayumba
# Processing Record 9 of Set 5 | andenes
# Processing Record 10 of Set 5 | takoradi
# Processing Record 11 of Set 5 | huanren
# Processing Record 12 of Set 5 | katobu
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | waipawa
# Processing Record 16 of Set 5 | paonta sahib
# Processing Record 17 of Set 5 | fort myers beach
# Processing Record 18 of Set 5 | sorong
# Processing Record 19 of Set 5 | bayanday
# Processing Record 20 of Set 5 | hailin
# Processing Record 21 of Set 5 | fare
# Processing Record 22 of Set 5 | clearwater
# Processing Record 23 of Set 5 | banjar
# Processing Record 24 of Set 5 | zachary
# Processing Record 25 of Set 5 | aksarka
# Processing Record 26 of Set 5 | elat
# Processing Record 27 of Set 5 | kirkwood
# Processing Record 28 of Set 5 | berlevag
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | ilulissat
# Processing Record 32 of Set 5 | verkhoshizhemye
# Processing Record 33 of Set 5 | namatanai
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | biak
# Processing Record 36 of Set 5 | carutapera
# Processing Record 37 of Set 5 | leh
# Processing Record 38 of Set 5 | bandarbeyla
# Processing Record 39 of Set 5 | kagadi
# Processing Record 40 of Set 5 | padang
# Processing Record 41 of Set 5 | cessnock
# Processing Record 42 of Set 5 | pingzhuang
# Processing Record 43 of Set 5 | srednekolymsk
# Processing Record 44 of Set 5 | dunedin
# Processing Record 45 of Set 5 | ixtapa
# Processing Record 46 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 5 | nemuro
# Processing Record 48 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 5 | katsuura
# Processing Record 0 of Set 6 | sao jose da coroa grande
# Processing Record 1 of Set 6 | simdega
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | tuktoyaktuk
# Processing Record 4 of Set 6 | rosetta
# Processing Record 5 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 6 | haines junction
# Processing Record 7 of Set 6 | los llanos de aridane
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | cap malheureux
# Processing Record 10 of Set 6 | sarankhola
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | aklavik
# Processing Record 13 of Set 6 | sao borja
# Processing Record 14 of Set 6 | lagoa
# Processing Record 15 of Set 6 | wana
# Processing Record 16 of Set 6 | mehamn
# Processing Record 17 of Set 6 | zinder
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | tabou
# Processing Record 20 of Set 6 | bjorkelangen
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | acapulco
# Processing Record 23 of Set 6 | mbanza-ngungu
# Processing Record 24 of Set 6 | veraval
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | fomboni
# Processing Record 27 of Set 6 | bogorodskoye
# Processing Record 28 of Set 6 | nouadhibou
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | saldanha
# Processing Record 31 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 32 of Set 6 | bethel
# Processing Record 33 of Set 6 | pevek
# Processing Record 34 of Set 6 | shelburne
# Processing Record 35 of Set 6 | sokoni
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | yulara
# Processing Record 38 of Set 6 | atambua
# Processing Record 39 of Set 6 | prieska
# Processing Record 40 of Set 6 | ravar
# Processing Record 41 of Set 6 | novobiryusinskiy
# Processing Record 42 of Set 6 | fatehpur
# Processing Record 43 of Set 6 | gimli
# Processing Record 44 of Set 6 | catarman
# Processing Record 45 of Set 6 | ucluelet
# Processing Record 46 of Set 6 | taksimo
# Processing Record 47 of Set 6 | anadyr
# Processing Record 48 of Set 6 | kavaratti
# Processing Record 49 of Set 6 | vanimo
# Processing Record 0 of Set 7 | erenhot
# Processing Record 1 of Set 7 | creel
# Processing Record 2 of Set 7 | tarrafal
# Processing Record 3 of Set 7 | olinda
# Processing Record 4 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 7 | along
# Processing Record 6 of Set 7 | alora
# Processing Record 7 of Set 7 | aykhal
# Processing Record 8 of Set 7 | kuching
# Processing Record 9 of Set 7 | gushikawa
# Processing Record 10 of Set 7 | umm lajj
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | klyuchi
# Processing Record 14 of Set 7 | matagami
# Processing Record 15 of Set 7 | taltal
# Processing Record 16 of Set 7 | yantzaza
# Processing Record 17 of Set 7 | faanui
# Processing Record 18 of Set 7 | osvaldo cruz
# Processing Record 19 of Set 7 | manta
# Processing Record 20 of Set 7 | morondava
# Processing Record 21 of Set 7 | belaya gora
# Processing Record 22 of Set 7 | charters towers
# Processing Record 23 of Set 7 | bagotville
# Processing Record 24 of Set 7 | kysyl-syr
# Processing Record 25 of Set 7 | urucui
# Processing Record 26 of Set 7 | antsirabe
# Processing Record 27 of Set 7 | tefe
# Processing Record 28 of Set 7 | montgomery
# Processing Record 29 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 7 | tuatapere
# Processing Record 32 of Set 7 | ahuimanu
# Processing Record 33 of Set 7 | puerto escondido
# Processing Record 34 of Set 7 | ulladulla
# Processing Record 35 of Set 7 | guider
# Processing Record 36 of Set 7 | mapiripan
# Processing Record 37 of Set 7 | christchurch
# Processing Record 38 of Set 7 | chiang mai
# Processing Record 39 of Set 7 | vanino
# Processing Record 40 of Set 7 | namibe
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | epe
# Processing Record 43 of Set 7 | tuy hoa
# Processing Record 44 of Set 7 | mildura
# Processing Record 45 of Set 7 | babati
# Processing Record 46 of Set 7 | boyolangu
# Processing Record 47 of Set 7 | satara
# Processing Record 48 of Set 7 | lavumisa
# Processing Record 49 of Set 7 | salalah
# Processing Record 0 of Set 8 | luwingu
# Processing Record 19 of Set 9 | mvangue
# Processing Record 20 of Set 9 | del rio
# Processing Record 21 of Set 9 | axim
# Processing Record 22 of Set 9 | kismayo
# Processing Record 23 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 9 | harnosand
# Processing Record 25 of Set 9 | galesong
# Processing Record 26 of Set 9 | caravelas
# Processing Record 27 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 9 | mpraeso
# Processing Record 29 of Set 9 | basco
# Processing Record 30 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 9 | palmer
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | zhaoyang
# Processing Record 34 of Set 9 | uyuni
# Processing Record 35 of Set 9 | ust-koksa
# Processing Record 36 of Set 9 | saint-augustin
# Processing Record 37 of Set 9 | poum
# Processing Record 38 of Set 9 | urumqi
# Processing Record 39 of Set 9 | praia da vitoria
# Processing Record 40 of Set 9 | fortuna
# Processing Record 41 of Set 9 | nuuk
# Processing Record 42 of Set 9 | soure
# Processing Record 43 of Set 9 | hovd
# Processing Record 44 of Set 9 | yumen
# Processing Record 45 of Set 9 | tahoua
# Processing Record 46 of Set 9 | babu
# Processing Record 47 of Set 9 | carballo
# Processing Record 48 of Set 9 | kaeo
# Processing Record 49 of Set 9 | santiago
# Processing Record 0 of Set 10 | isangel
# Processing Record 1 of Set 10 | noumea
# Processing Record 2 of Set 10 | parsabad
# Processing Record 3 of Set 10 | tual
# Processing Record 4 of Set 10 | arcata
# Processing Record 5 of Set 10 | trincomalee
# Processing Record 6 of Set 10 | lahij
# Processing Record 7 of Set 10 | oskarshamn
# Processing Record 8 of Set 10 | talara
# Processing Record 9 of Set 10 | nanakuli
# Processing Record 10 of Set 10 | port hedland
# Processing Record 11 of Set 10 | mabamba
# Processing Record 12 of Set 10 | port blair
# Processing Record 13 of Set 10 | redmond
# Processing Record 14 of Set 10 | ilinskiy
# Processing Record 15 of Set 10 | challapata
# Processing Record 16 of Set 10 | gat
# Processing Record 17 of Set 10 | ampanihy
# Processing Record 18 of Set 10 | alta floresta
# Processing Record 19 of Set 10 | msanga
# Processing Record 20 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 10 | praya
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | hunchun
# Processing Record 24 of Set 10 | kenai
# Processing Record 25 of Set 10 | aktau
# Processing Record 26 of Set 10 | berbera
# Processing Record 27 of Set 10 | paamiut
# Processing Record 28 of Set 10 | amahai
# Processing Record 29 of Set 10 | bubaque
# Processing Record 30 of Set 10 | abu dhabi
# Processing Record 31 of Set 10 | la palma
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | asfi
# Processing Record 34 of Set 10 | petrolia
# Processing Record 35 of Set 10 | elko
# Processing Record 36 of Set 10 | guane
# Processing Record 37 of Set 10 | karari
# Processing Record 38 of Set 10 | genhe
# Processing Record 39 of Set 10 | milkovo
# Processing Record 40 of Set 10 | owosso
# Processing Record 41 of Set 10 | jawhar
# Processing Record 42 of Set 10 | fethiye
# Processing Record 43 of Set 10 | dahuk
# Processing Record 44 of Set 10 | andros town
# Processing Record 45 of Set 10 | farim
# Processing Record 46 of Set 10 | muros
# Processing Record 47 of Set 10 | lompoc
# Processing Record 48 of Set 10 | santa maria
# Processing Record 49 of Set 10 | altay
# Processing Record 0 of Set 11 | mehar
# Processing Record 1 of Set 11 | pendleton
# Processing Record 2 of Set 11 | moyale
# Processing Record 3 of Set 11 | mitsamiouli
# Processing Record 4 of Set 11 | fort dodge
# Processing Record 5 of Set 11 | meulaboh
# Processing Record 6 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 11 | solnechnoye
# Processing Record 8 of Set 11 | sungai besar
# Processing Record 9 of Set 11 | maceio
# Processing Record 10 of Set 11 | yerbogachen
# Processing Record 11 of Set 11 | cortez
# Processing Record 12 of Set 11 | chernyshevskiy
# Processing Record 13 of Set 11 | kruisfontein
# Processing Record 14 of Set 11 | key west
# Processing Record 15 of Set 11 | nuwara eliya
# Processing Record 16 of Set 11 | talnakh
# Processing Record 17 of Set 11 | san patricio
# Processing Record 18 of Set 11 | moron
# Processing Record 19 of Set 11 | visnes
# Processing Record 20 of Set 11 | belmonte
# Processing Record 21 of Set 11 | alugan
# Processing Record 22 of Set 11 | samarai
# Processing Record 23 of Set 11 | samus
# Processing Record 24 of Set 11 | san pedro del parana
# Processing Record 25 of Set 11 | hwange
# Processing Record 26 of Set 11 | usakos
# Processing Record 27 of Set 11 | mattawa
# Processing Record 28 of Set 11 | sabang
# Processing Record 29 of Set 11 | kostomuksha
# Processing Record 30 of Set 11 | ketchikan
# Processing Record 31 of Set 11 | joshimath
# Processing Record 32 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 33 of Set 11 | abu samrah
# Processing Record 34 of Set 11 | flin flon
# Processing Record 35 of Set 11 | fairbanks
# Processing Record 36 of Set 11 | chateaubelair
# Processing Record 37 of Set 11 | omboue
# Processing Record 38 of Set 11 | sauce
# Processing Record 39 of Set 11 | tezu
# Processing Record 40 of Set 11 | alamosa
# Processing Record 41 of Set 11 | darnah
# Processing Record 42 of Set 11 | pandan
# Processing Record 43 of Set 11 | itaituba
# Processing Record 44 of Set 11 | bichura
# Processing Record 45 of Set 11 | kalangala
# Processing Record 46 of Set 11 | pryluky
# Processing Record 47 of Set 11 | searcy
# Processing Record 48 of Set 11 | byron bay
# Processing Record 49 of Set 11 | husavik
# Processing Record 0 of Set 12 | tlapehuala
# Processing Record 1 of Set 12 | verkh-usugli
# Processing Record 2 of Set 12 | ambon
# Processing Record 3 of Set 12 | arnprior
# Processing Record 4 of Set 12 | panjakent
# Processing Record 5 of Set 12 | vuktyl
# Processing Record 6 of Set 12 | nevelsk
# Processing Record 7 of Set 12 | huntsville
# Processing Record 8 of Set 12 | shubarkuduk
# Processing Record 9 of Set 12 | virginia beach
# Processing Record 10 of Set 12 | lunenburg
# Processing Record 11 of Set 12 | gravelbourg
# Processing Record 12 of Set 12 | leopold
# Processing Record 13 of Set 12 | ladybrand
# Processing Record 14 of Set 12 | xining
# Processing Record 15 of Set 12 | alexandria
# Processing Record 16 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 12 | khani
# Processing Record 18 of Set 12 | tilichiki
# Processing Record 19 of Set 12 | haskovo
# Processing Record 20 of Set 12 | arica
# Processing Record 21 of Set 12 | la macarena
# Processing Record 22 of Set 12 | bafilo
# Processing Record 23 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 12 | yacuiba
# Processing Record 25 of Set 12 | pachino
# Processing Record 26 of Set 12 | ohara
# Processing Record 27 of Set 12 | yuanping
# Processing Record 28 of Set 12 | kuusamo
# Processing Record 29 of Set 12 | akdepe
# Processing Record 30 of Set 12 | payo
# Processing Record 31 of Set 12 | salitral
# Processing Record 32 of Set 12 | ola
# Processing Record 33 of Set 12 | tanout
# Processing Record 34 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 12 | tanabe
# Processing Record 36 of Set 12 | yar-sale
# Processing Record 37 of Set 12 | avera
# Processing Record 38 of Set 12 | bandiagara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       avarua -21.2078 -159.7750     28.03        74           9        2.57
# 1  clyde river  70.4692  -68.5914    -27.87        69         100        8.23
# 2     marshall  34.3834  -86.3333     12.84        37           0        2.06
# 3       hobart -42.8794  147.3294     16.14        93          20        3.09
# 4     buchanan   5.8808  -10.0467     26.39        84         100        2.61
#
#   Country               Date
# 0      CK  01/24/23,19:49:22
# 1      CA  01/24/23,19:49:23
# 2      US  01/24/23,19:49:23
# 3      AU  01/24/23,19:48:06
# 4      LR  01/24/23,19:49:24

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             avarua -21.2078 -159.7750     28.03        74           9
# 1        clyde river  70.4692  -68.5914    -27.87        69         100
# 2           marshall  34.3834  -86.3333     12.84        37           0
# 3             hobart -42.8794  147.3294     16.14        93          20
# 4           buchanan   5.8808  -10.0467     26.39        84         100
#
#          Wind Speed Country               Date
# City_ID
# 0              2.57      CK  01/24/23,19:49:22
# 1              8.23      CA  01/24/23,19:49:23
# 2              2.06      US  01/24/23,19:49:23
# 3              3.09      AU  01/24/23,19:48:06
# 4              2.61      LR  01/24/23,19:49:24

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature" + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

plt.scatter(city_data_df["Lat"],city_data_df["Humidity"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity"  + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness"  + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed"  + '(' + str(pd.datetime.now().date()) + ')')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearregression(x, y):
    (slope, intercept, r, p, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    plt.plot(x_values,regress_values, color='darkred', linewidth=2)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df[city_data_df['Lat'] >= 0])

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        clyde river  70.4692  -68.5914    -27.87        69         100
# 2           marshall  34.3834  -86.3333     12.84        37           0
# 4           buchanan   5.8808  -10.0467     26.39        84         100
# 5         nanortalik  60.1432  -45.2371     -3.18        83         100
# 6               hilo  19.7297 -155.0900     26.82        78          75
#
#          Wind Speed Country               Date
# City_ID
# 1              8.23      CA  01/24/23,19:49:23
# 2              2.06      US  01/24/23,19:49:23
# 4              2.61      LR  01/24/23,19:49:24
# 5              5.27      GL  01/24/23,19:49:24
# 6              3.13      US  01/24/23,19:47:33

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df[city_data_df['Lat'] < 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             avarua -21.2078 -159.7750     28.03        74           9
# 3             hobart -42.8794  147.3294     16.14        93          20
# 11       nova aurora -22.8667  -52.5667     31.60        45          26
# 12             gamba  -2.6500   10.0000     25.70        80          91
# 16             airai  -8.9266  125.4092     15.90        93          86
#
#          Wind Speed Country               Date
# City_ID
# 0              2.57      CK  01/24/23,19:49:22
# 3              3.09      AU  01/24/23,19:48:06
# 11             1.42      BR  01/24/23,19:49:27
# 12             1.06      GA  01/24/23,19:49:27
# 16             0.59      TL  01/24/23,19:49:29

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude'  + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(1, -50), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig5.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.67

# %%
# Linear regression on Southern Hemisphere

# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-55, 30), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig6.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.15

# %% [markdown]
# **Discussion about the linear relationship:**
#
# For the Northern Hemisphere, the cities' latitude and max temperature has a moderately strong linear relationship as indicated by the r-squared value of 0.67. (Usually, the larger the R2 value, the greater the regression model fits observations.)
#
# For the Southern Hemisphere, the cities' latitude and max temperature has a minimal linear relationship as indicated by it's R2 value of 0.15. (Usually, the lower the R2 value, the less a regression model fits observations.)

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(45, 15), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig7.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.21

# %%
# Southern Hemisphere
# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-18, 20), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig8.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.11

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Both hemisphere's had low R2 values: Northern at 0.21 and Southern at 0.11.  This indicates a moderate to minimal linear relationship.  (Usually, an R2 value of 0% means that all movements of a dependent variable are completely NOT explained by movements in the independent variable.)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(55, 15), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig9.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.07

# %%
# Southern Hemisphere
# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-18, 4), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig10.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.14

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Both hemisphere's had low R2 values: Northern at 0.07 and Southern at 0.14.  This indicates an insignificant to minimal linear relationship.  (Usually, an R2 value of 0% means that all movements of a dependent variable are completely NOT explained by movements in the independent variable.)

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(45, 15), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig11.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.0

# %%
# Southern Hemisphere
# Build scatter plot for each data type
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Perform a linear regression for temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values)
linearregression(x_values, y_values)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude'   + '(' + str(pd.datetime.now().date()) + ')')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.annotate(line_eq,(-30, 10), fontsize=12, color='darkred')

# Print the r-squared value
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/Fig12.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.12

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Both hemisphere's had low R2 values: Northern at 0.0 and Southern at 0.12.  This indicates a non-existent to insignificant linear relationship.  (Usually, an R2 value of 0% means that all movements of a dependent variable are completely NOT explained by movements in the independent variable.)
